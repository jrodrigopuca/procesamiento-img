# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
imagen = cv2.imread("img/boy.png")
rgb= cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)
plt.imshow(rgb)
plt.title('Original')
# Out:
# Text(0.5,1,'Original')

# %%
# Filtro gaussiano
# sigma= 17, hsize = 1,3,50

blur1 = cv2.GaussianBlur(rgb,(17,17),1)
blur2 = cv2.GaussianBlur(rgb,(17,17),3)
blur3 = cv2.GaussianBlur(rgb,(17,17),50)

plt.subplot(131),plt.imshow(blur1),plt.axis('off')
plt.subplot(132),plt.imshow(blur2),plt.axis('off')
plt.subplot(133),plt.imshow(blur3),plt.axis('off')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0xe4b5470>,
# ...
#  (-0.5, 239.5, 239.5, -0.5))

# %%
# filtro de la mediana
median1 = cv2.medianBlur(rgb,5)
median2 = cv2.medianBlur(rgb,11)
median3 = cv2.medianBlur(rgb,17)

plt.subplot(131),plt.imshow(median1),plt.axis('off')
plt.subplot(132),plt.imshow(median2),plt.axis('off')
plt.subplot(133),plt.imshow(median3),plt.axis('off')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0xba8dfd0>,
# ...
#  (-0.5, 239.5, 239.5, -0.5))

# %%
# filtro de la media
blur1 = cv2.blur(rgb,(3,3))
blur2 = cv2.blur(rgb,(11,11))
blur3 = cv2.blur(rgb,(17,17))

plt.subplot(131),plt.imshow(blur1),plt.axis('off')
plt.subplot(132),plt.imshow(blur2),plt.axis('off')
plt.subplot(133),plt.imshow(blur3),plt.axis('off')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0xbbb7310>,
# ...
#  (-0.5, 239.5, 239.5, -0.5))
