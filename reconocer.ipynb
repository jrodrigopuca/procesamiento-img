# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %%
face_cascade = cv.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv.CascadeClassifier('haarcascade_eye.xml')
img = cv.imread('kppa.png')
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
plt.imshow(img)

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    cv.rectangle(img,(x,y),(x+w,y+h),(255,255,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        #cv.Rectangle(img, pt1, pt2, color, thickness=1, lineType=8, shift=0) 
        #cv.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        #cv.Circle(img, center, radius, color, thickness=1, lineType=8, shift=0)
        cv.circle(roi_color, (ex+ew//2,ey+eh//2), 10,(0,255,9),20)
plt.imshow(img, cmap='gray')
cv.imwrite("sv-1.png", img)
# Out:
# True

# %%
imgMask= cv.imread('mask1.png')
dst = cv.addWeighted(img,0.7,imgMask,0.3,0)
plt.imshow(dst)

# %%
#img2 = cv.imread('emoji.png')
#rows,cols,channels = img2.shape
#roi = img[0:rows, 0:cols ]
#img2gray = cv.cvtColor(img2,cv.COLOR_BGR2GRAY)
#ret, mask = cv.threshold(img2gray, 200, 250, cv.THRESH_BINARY)
#mask_inv = cv.bitwise_not(mask)
#img1_bg = cv.bitwise_and(roi,roi,mask = mask_inv)
#img2_fg = cv.bitwise_and(img2,img2,mask = mask)
#img[0:rows, 0:cols] = dst
#dst = cv.add(img1_bg,img2_fg)
#plt.imshow(dst)

parte=gray[160:300, 160:300]
#print(parte.shape) 140 149 3
#plt.imshow(parte)
rows,cols=parte.shape

#roi=gray[10:rows, 10:cols] #desde el 10 al 150 
plt.imshow(roi)

ret, mask = cv.threshold(gray, 140, 240, cv.THRESH_BINARY)
mask_inv = cv.bitwise_not(mask)

gray[100:rows+100:1, 100:cols+100:1]= parte[::1,::1]
plt.imshow(gray)
